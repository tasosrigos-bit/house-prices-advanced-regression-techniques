# %% [markdown]
# # Linear Regression
#
# In this notebook, we will use the Linear Regression for predicting the price of a house based on its feature. We will use the `scikit-learn` library to implement the Linear Regression model.
