# %% [markdown]
# # Linear Regression
#
# In this notebook, we will use the Linear Regression for predicting the price of a house based on its feature. We will use the `scikit-learn` library to implement the Linear Regression model.

# %% [markdown]
# ## Setting up the environment
#
# First, we need to import the necessary libraries and load the dataset. As far as the dataset is concerned, we will use the `train.csv` file from the Kaggle competition, which contains the training data for our model and we will use the `test.csv` file for making predictions and submitting to the competition.

# %% [markdown]
# import sklearn
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Full Model
#
# We will start by building a linear regression model using all the features in the dataset. This will serve as our baseline model, and we will evaluate its performance using the Root Mean Squared Error (RMSE) metric.
